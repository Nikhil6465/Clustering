# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from scipy import stats
import seaborn as sns 
from sklearn.cluster import KMeans
from scipy.spatial.distance import cdist 
import matplotlib.cm as cm
import scipy.cluster.hierarchy as sch
from sklearn.cluster import AgglomerativeClustering

# %%
airline_data = pd.read_csv('EastWestAirlines.csv')
airline_data
# Out:
#        ID#  Balance  Qual_miles  cc1_miles  cc2_miles  cc3_miles  Bonus_miles  \
# 0        1    28143           0          1          1          1          174
# 1        2    19244           0          1          1          1          215
# 2        3    41354           0          1          1          1         4123
# 3        4    14776           0          1          1          1          500
# 4        5    97752           0          4          1          1        43300
# ...    ...      ...         ...        ...        ...        ...          ...
# 3994  4017    18476           0          1          1          1         8525
# 3995  4018    64385           0          1          1          1          981
# 3996  4019    73597           0          3          1          1        25447
# 3997  4020    54899           0          1          1          1          500
# 3998  4021     3016           0          1          1          1            0
#
# ...

# %%
del airline_data['ID#']

# %%
airline_data.shape
# Out:
# (3999, 11)

# %%
airline_data.isna().sum()
# Out:
# Balance              0
# Qual_miles           0
# cc1_miles            0
# cc2_miles            0
# cc3_miles            0
# Bonus_miles          0
# Bonus_trans          0
# Flight_miles_12mo    0
# Flight_trans_12      0
# Days_since_enroll    0
# Award?               0
# dtype: int64

# %%
airline_data.describe()
# Out:
#             Balance    Qual_miles    cc1_miles    cc2_miles    cc3_miles  \
# count  3.999000e+03   3999.000000  3999.000000  3999.000000  3999.000000
# mean   7.360133e+04    144.114529     2.059515     1.014504     1.012253
# std    1.007757e+05    773.663804     1.376919     0.147650     0.195241
# min    0.000000e+00      0.000000     1.000000     1.000000     1.000000
# 25%    1.852750e+04      0.000000     1.000000     1.000000     1.000000
# 50%    4.309700e+04      0.000000     1.000000     1.000000     1.000000
# 75%    9.240400e+04      0.000000     3.000000     1.000000     1.000000
# max    1.704838e+06  11148.000000     5.000000     3.000000     5.000000
#
#          Bonus_miles  Bonus_trans  Flight_miles_12mo  Flight_trans_12  \
# count    3999.000000   3999.00000        3999.000000      3999.000000
# mean    17144.846212     11.60190         460.055764         1.373593
# std     24150.967826      9.60381        1400.209171         3.793172
# ...

# %%
airline_data.nunique()
# Out:
# Balance              3904
# Qual_miles            164
# cc1_miles               5
# cc2_miles               3
# cc3_miles               5
# Bonus_miles          2734
# Bonus_trans            57
# Flight_miles_12mo     343
# Flight_trans_12        35
# Days_since_enroll    2820
# Award?                  2
# dtype: int64

# %%
airline_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3999 entries, 0 to 3998
# Data columns (total 11 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Balance            3999 non-null   int64
#  1   Qual_miles         3999 non-null   int64
#  2   cc1_miles          3999 non-null   int64
#  3   cc2_miles          3999 non-null   int64
#  4   cc3_miles          3999 non-null   int64
#  5   Bonus_miles        3999 non-null   int64
#  6   Bonus_trans        3999 non-null   int64
#  7   Flight_miles_12mo  3999 non-null   int64
#  8   Flight_trans_12    3999 non-null   int64
#  9   Days_since_enroll  3999 non-null   int64
#  10  Award?             3999 non-null   int64
# dtypes: int64(11)
# memory usage: 343.8 KB

# %%
airline_data.hist(figsize = (18,10))
plt.show()

# %%
airline_data.corr()
# Out:
#                     Balance  Qual_miles  cc1_miles  cc2_miles  cc3_miles  \
# Balance            1.000000    0.108722   0.338344  -0.008804   0.035243
# Qual_miles         0.108722    1.000000   0.007931  -0.013923  -0.007779
# cc1_miles          0.338344    0.007931   1.000000  -0.068223   0.060555
# cc2_miles         -0.008804   -0.013923  -0.068223   1.000000  -0.006166
# cc3_miles          0.035243   -0.007779   0.060555  -0.006166   1.000000
# Bonus_miles        0.403487    0.031021   0.825200  -0.003969   0.204134
# Bonus_trans        0.324935    0.050725   0.608943   0.064399   0.097313
# Flight_miles_12mo  0.217551    0.126774   0.037370   0.010598  -0.001777
# Flight_trans_12    0.255700    0.144004   0.041333   0.028284  -0.001117
# Days_since_enroll  0.263129    0.017312   0.230849  -0.005807   0.010832
# Award?             0.178494    0.095256   0.335457   0.005332   0.023484
#
#                    Bonus_miles  Bonus_trans  Flight_miles_12mo  \
# ...

# %%
plt.figure(figsize=(20,12))
sns.heatmap(airline_data.corr(),annot=True)
plt.show()

# %% [markdown]
# ### Hierarchy Clustring

# %%
from sklearn.preprocessing import normalize
Airline_norm=pd.DataFrame(normalize(airline_data),columns=airline_data.columns)
Airline_norm
# Out:
#        Balance  Qual_miles  cc1_miles  cc2_miles  cc3_miles  Bonus_miles  \
# 0     0.970414         0.0   0.000034   0.000034   0.000034     0.006000
# 1     0.940209         0.0   0.000049   0.000049   0.000049     0.010504
# 2     0.981113         0.0   0.000024   0.000024   0.000024     0.097817
# 3     0.904428         0.0   0.000061   0.000061   0.000061     0.030605
# 4     0.912226         0.0   0.000037   0.000009   0.000009     0.404078
# ...        ...         ...        ...        ...        ...          ...
# 3994  0.905810         0.0   0.000049   0.000049   0.000049     0.417949
# 3995  0.999649         0.0   0.000016   0.000016   0.000016     0.015231
# 3996  0.944948         0.0   0.000039   0.000013   0.000013     0.326726
# 3997  0.999592         0.0   0.000018   0.000018   0.000018     0.009104
# 3998  0.907271         0.0   0.000301   0.000301   0.000301     0.000000
#
#       Bonus_trans  Flight_miles_12mo  Flight_trans_12  Days_since_enroll  \
# ...

# %%
dendrogram=sch.dendrogram(sch.linkage(Airline_norm,method='average'))

# %%
hc=AgglomerativeClustering(n_clusters=5,affinity='euclidean',linkage='ward')

# %%
y=pd.DataFrame(hc.fit_predict(Airline_norm),columns=['clusters'])

# %%
airline_data['clustering']=hc.labels_

# %%
airline_data.groupby('clustering').agg(['mean']).reset_index()
# Out:
#   clustering       Balance  Qual_miles cc1_miles cc2_miles cc3_miles  \
#                       mean        mean      mean      mean      mean
# 0          0   5524.222707    8.755459  1.000000  1.000000  1.000000
# 1          1  31066.514349  111.415011  3.200883  1.026490  1.070640
# 2          2  81201.080802  136.521008  2.115061  1.013575  1.000646
# 3          3  69569.894646   97.257340  3.326425  1.032815  1.022453
# 4          4  94957.590260  215.220823  1.141058  1.005038  1.002519
#
#     Bonus_miles Bonus_trans Flight_miles_12mo Flight_trans_12  \
#            mean        mean              mean            mean
# 0    584.532751    2.401747         66.982533        0.209607
# 1  40266.935982   17.289183        626.754967        1.812362
# 2  16350.149968   13.574014        488.550743        1.340659
# 3  35743.675302   17.784111        406.804836        1.274611
# 4   3524.928631    5.640638        461.104954        1.521411
#
#   Days_since_enroll    Award?
# ...

# %%
plt.figure(figsize=(10, 6))  
plt.scatter(airline_data['clustering'],airline_data['Balance'], c=hc.labels_)
plt.show()

# %% [markdown]
# ### K-Mean Clustering

# %%
from sklearn.cluster import KMeans
from sklearn.preprocessing import StandardScaler

# %%
Airline_norm2=StandardScaler().fit_transform(airline_data)
Airline_norm2
# Out:
# array([[-4.51140783e-01, -1.86298687e-01, -7.69578406e-01, ...,
#          1.39545434e+00, -7.66919299e-01,  1.25009890e+00],
#        [-5.39456874e-01, -1.86298687e-01, -7.69578406e-01, ...,
#          1.37995704e+00, -7.66919299e-01, -4.30851168e-01],
#        [-3.20031232e-01, -1.86298687e-01, -7.69578406e-01, ...,
#          1.41192021e+00, -7.66919299e-01, -4.30851168e-01],
#        ...,
#        [-4.29480975e-05, -1.86298687e-01,  6.83121167e-01, ...,
#         -1.31560393e+00,  1.30391816e+00, -4.30851168e-01],
#        [-1.85606976e-01, -1.86298687e-01, -7.69578406e-01, ...,
#         -1.31608822e+00, -7.66919299e-01,  1.25009890e+00],
#        [-7.00507951e-01, -1.86298687e-01, -7.69578406e-01, ...,
#         -1.31754109e+00, -7.66919299e-01, -4.30851168e-01]])

# %%
wcss=[]
for i in range (1,11):
    kmeans=KMeans(n_clusters=i,random_state=2)
    kmeans.fit(Airline_norm2)
    wcss.append(kmeans.inertia_)

# %%
plt.plot(range(1,11),wcss)
plt.title('Elbow Graph')
plt.xlabel('Number of clusters')
plt.ylabel('WCSS')
plt.show()

# %% [markdown]
# ### Build Cluster algorithm using K=6

# %%
clusters6=KMeans(6,random_state=30).fit(Airline_norm2)
clusters6
# Out:
# KMeans(n_clusters=6, random_state=30)

# %%
clusters6.labels_
# Out:
# array([1, 2, 2, ..., 2, 1, 2])

# %%
Airline_norm3 = airline_data.copy()
Airline_norm3 ['clustersing'] = clusters6.labels_
Airline_norm3.head()
# Out:
#    Balance  Qual_miles  cc1_miles  cc2_miles  cc3_miles  Bonus_miles  \
# 0    28143           0          1          1          1          174
# 1    19244           0          1          1          1          215
# 2    41354           0          1          1          1         4123
# 3    14776           0          1          1          1          500
# 4    97752           0          4          1          1        43300
#
#    Bonus_trans  Flight_miles_12mo  Flight_trans_12  Days_since_enroll  Award?  \
# 0            1                  0                0               7000       0
# 1            2                  0                0               6968       0
# 2            4                  0                0               7034       0
# 3            1                  0                0               6952       0
# 4           26               2077                4               6935       1
#
#    clustering  clustersing
# 0           4            1
# ...

# %%
Airline_norm3.groupby('clustersing').agg(['mean']).reset_index()
# Out:
#   clustersing        Balance  Qual_miles cc1_miles cc2_miles cc3_miles  \
#                         mean        mean      mean      mean      mean
# 0           0  122218.456912  156.967684  3.864452  1.000000  1.001795
# 1           1   65904.454787  161.156915  1.063830  1.000000  1.000000
# 2           2   31865.099676   59.786408  1.484790  1.000000  1.000647
# 3           3  138061.400000   78.800000  3.466667  1.000000  4.066667
# 4           4  192051.493506  812.435065  2.181818  1.000000  1.000000
# 5           5   68876.581395   23.255814  1.139535  2.348837  1.000000
#
#     Bonus_miles Bonus_trans Flight_miles_12mo Flight_trans_12  \
#            mean        mean              mean            mean
# 0  42530.673250   19.147217        370.964093        1.098743
# 1   2473.540780    4.417553        236.776596        0.770390
# 2   7386.488673    9.530744        176.296440        0.517799
# 3  93927.866667   28.066667        506.666667        1.600000
# ...

# %%
plt.figure(figsize=(10, 6))  
plt.scatter(Airline_norm3['clustersing'],Airline_norm3['Qual_miles'], c=clusters6.labels_) 
plt.show()

# %% [markdown]
# ### DBSCAN Clustering

# %%
from sklearn.cluster import DBSCAN
from sklearn.preprocessing import StandardScaler

# %%
Airline_norm4=StandardScaler().fit_transform(airline_data)
Airline_norm4
# Out:
# array([[-4.51140783e-01, -1.86298687e-01, -7.69578406e-01, ...,
#          1.39545434e+00, -7.66919299e-01,  1.25009890e+00],
#        [-5.39456874e-01, -1.86298687e-01, -7.69578406e-01, ...,
#          1.37995704e+00, -7.66919299e-01, -4.30851168e-01],
#        [-3.20031232e-01, -1.86298687e-01, -7.69578406e-01, ...,
#          1.41192021e+00, -7.66919299e-01, -4.30851168e-01],
#        ...,
#        [-4.29480975e-05, -1.86298687e-01,  6.83121167e-01, ...,
#         -1.31560393e+00,  1.30391816e+00, -4.30851168e-01],
#        [-1.85606976e-01, -1.86298687e-01, -7.69578406e-01, ...,
#         -1.31608822e+00, -7.66919299e-01,  1.25009890e+00],
#        [-7.00507951e-01, -1.86298687e-01, -7.69578406e-01, ...,
#         -1.31754109e+00, -7.66919299e-01, -4.30851168e-01]])

# %%
dbscan=DBSCAN(eps=1,min_samples=6)
dbscan.fit(Airline_norm4)
# Out:
# DBSCAN(eps=1, min_samples=6)

# %%
dbscan.labels_
# Out:
# array([0, 0, 0, ..., 1, 0, 0], dtype=int64)

# %%
airline_data['clusters']=dbscan.labels_
airline_data
# Out:
#       Balance  Qual_miles  cc1_miles  cc2_miles  cc3_miles  Bonus_miles  \
# 0       28143           0          1          1          1          174
# 1       19244           0          1          1          1          215
# 2       41354           0          1          1          1         4123
# 3       14776           0          1          1          1          500
# 4       97752           0          4          1          1        43300
# ...       ...         ...        ...        ...        ...          ...
# 3994    18476           0          1          1          1         8525
# 3995    64385           0          1          1          1          981
# 3996    73597           0          3          1          1        25447
# 3997    54899           0          1          1          1          500
# 3998     3016           0          1          1          1            0
#
#       Bonus_trans  Flight_miles_12mo  Flight_trans_12  Days_since_enroll  \
# ...

# %%
airline_data.groupby('clusters').agg(['mean']).reset_index()
# Out:
#   clusters        Balance  Qual_miles cc1_miles cc2_miles cc3_miles  \
#                      mean        mean      mean      mean      mean
# 0       -1  162135.141399  824.574344  2.606414  1.069971  1.071429
# 1        0   53135.599473    2.252964  1.655687  1.000000  1.000000
# 2        1   57199.235764    5.520480  2.592408  1.000000  1.000000
# 3        2  276972.111111    0.000000  5.000000  1.000000  1.000000
# 4        3  217864.166667    0.000000  3.000000  1.000000  1.000000
# 5        4   79193.833333    0.000000  1.000000  1.000000  1.000000
# 6        5   30005.800000    0.000000  1.000000  2.000000  1.000000
# 7        6   71413.000000    0.000000  1.000000  1.000000  1.000000
#
#     Bonus_miles Bonus_trans Flight_miles_12mo Flight_trans_12  \
#            mean        mean              mean            mean
# 0  36091.788630   20.695335       2015.371720        5.776968
# 1   8925.722003    8.389987        101.137901        0.339482
# ...

# %%
plt.figure(figsize=(10, 6))  
plt.scatter(airline_data['clusters'],airline_data['Balance'], c=dbscan.labels_) 
plt.show()
